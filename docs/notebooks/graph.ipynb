# %%
pip install networkx
# Out:
# Collecting networkx
#   Using cached networkx-2.8-py3-none-any.whl (2.0 MB)
# Installing collected packages: networkx
# Successfully installed networkx-2.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()

data = [('A', 'B', 3), ('A', 'C',2), ('D', 'B', 5), ('E', 'C', 6), ('E', 'F',7),
     ('B', 'H', 9), ('B', 'G', 10), ('B', 'F', 12), ('C', 'G', 5)]

for s, t, w in data:
    G.add_edge(s, t, weight=w)

node_edges = [(u, v) for (u, v, d) in G.edges(data=True)]

pos = nx.spring_layout(G, seed=7)  # positions for all nodes - seed for reproducibility

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=node_edges, width=6)

# labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
plt.show()
